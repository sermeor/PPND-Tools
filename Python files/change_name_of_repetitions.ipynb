# %%
import os

def get_files(directory):

    for root, dirs, files in os.walk(directory):
        for file in files:
            splits = file.split('.')
            file_name = splits[0]
            format_name = splits[1]
            if file_name.endswith(')'):
                number = file_name[-2]
                print(file_name)
                new_file_name = file_name[:-4] + '_' + number +'.'+ format_name
                print(new_file_name)
                old_filepath = os.path.join(root, file)
                new_filepath = os.path.join(root, new_file_name)
                #os.rename(old_filepath, new_filepath)
            

dir = "TRFEP"
list_of_files = get_files(dir)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-3ed952102854> in <module>
#      19
#      20 dir = "TRFEP"
# ---> 21 list_of_files = get_files(dir)
#
# <ipython-input-2-3ed952102854> in get_files(directory)
#       7             splits = file.split('.')
#       8             file_name = splits[0]
# ----> 9             format_name = splits[1]
#      10             if file_name.endswith(')'):
#      11                 number = file_name[-2]
#
# IndexError: list index out of range
